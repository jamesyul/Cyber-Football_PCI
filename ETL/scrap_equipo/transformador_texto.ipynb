# %%
import pandas as pd

df = pd.read_csv("/Users/yulcardaso/Desktop/NUEVO_CURSO/PCI/Cyber-Football_PCI/ETL/scrap_equipo/equipin.csv")

url_madrid = 'https://cdn.gomister.com/file/cdn-common/teams/15.png?version=20240110'
url_girona = 'https://cdn.gomister.com/file/cdn-common/teams/222.png?version=20240110'
url_barcelona = 'https://cdn.gomister.com/file/cdn-common/teams/3.png?version=20240110'
url_athletic = 'https://cdn.gomister.com/file/cdn-common/teams/1.png?version=20240110'
url_atletico = 'https://cdn.gomister.com/file/cdn-common/teams/2.png?version=20240110'
url_realsociedad = 'https://cdn.gomister.com/file/cdn-common/teams/16.png?version=20240110'
url_betis = 'https://cdn.gomister.com/file/cdn-common/teams/4.png?version=20240110'
url_getafe = 'https://cdn.gomister.com/file/cdn-common/teams/9.png?version=20240110'
url_valencia = 'https://cdn.gomister.com/file/cdn-common/teams/19.png?version=20240110'
url_las_palmas = 'https://cdn.gomister.com/file/cdn-common/teams/11.png?version=20240110'
url_rayo = 'https://cdn.gomister.com/file/cdn-common/teams/14.png?version=20240110'
url_osasuna = 'https://cdn.gomister.com/file/cdn-common/teams/50.png?version=20240110'
url_villareal = 'https://cdn.gomister.com/file/cdn-common/teams/20.png?version=20240110'
url_mallorca = 'https://cdn.gomister.com/file/cdn-common/teams/408.png?version=20240110'
url_alaves = 'https://cdn.gomister.com/file/cdn-common/teams/48.png?version=20240110'
url_sevilla = 'https://cdn.gomister.com/file/cdn-common/teams/17.png?version=20240110'
url_celta = 'https://cdn.gomister.com/file/cdn-common/teams/5.png?version=20240110'
url_cadiz = 'https://cdn.gomister.com/file/cdn-common/teams/499.png?version=20240110'
url_granada = 'https://cdn.gomister.com/file/cdn-common/teams/10.png?version=20240110'
url_almeria = 'https://cdn.gomister.com/file/cdn-common/teams/21.png?version=20240110'



# Función para reemplazar la URL por una palabra
def reemplazar_url_por_palabra(texto):
     if texto == "https://cdn.gomister.com/file/cdn-common/teams/15.png?version=20240121":
        return "Real Madrid Club de Fútbol"
     elif texto == 'https://cdn.gomister.com/file/cdn-common/teams/222.png?version=20240121':
        return 'Girona Fútbol Club'
     elif texto == 'https://cdn.gomister.com/file/cdn-common/teams/3.png?version=20240121':
        return 'Fútbol Club Barcelona'
     elif texto == 'https://cdn.gomister.com/file/cdn-common/teams/1.png?version=20240114':
        return 'Athletic Club'
     elif texto == 'https://cdn.gomister.com/file/cdn-common/teams/2.png?version=20240121':
        return 'Club Atlético de Madrid'
     elif texto == 'https://cdn.gomister.com/file/cdn-common/teams/16.png?version=20240121':
        return 'Real Sociedad de Fútbol'
     elif texto == 'https://cdn.gomister.com/file/cdn-common/teams/4.png?version=20240121':
        return 'Real Betis Balompié'
     elif texto == 'https://cdn.gomister.com/file/cdn-common/teams/9.png?version=20240121':
        return 'Getafe Club de Fútbol'
     elif texto == 'https://cdn.gomister.com/file/cdn-common/teams/19.png?version=20240121':
        return 'Valencia Club de Fútbol'
     elif texto ==  'https://cdn.gomister.com/file/cdn-common/teams/11.png?version=20240121':
        return 'Unión Deportiva Las Palmas'
     elif texto == 'https://cdn.gomister.com/file/cdn-common/teams/14.png?version=20240121':
        return 'Rayo Vallecano de Madrid'
     elif texto == 'https://cdn.gomister.com/file/cdn-common/teams/50.png?version=20240121':
        return 'Club Atlético Osasuna'
     elif texto == 'https://cdn.gomister.com/file/cdn-common/teams/20.png?version=20240121':
        return 'Villarreal Club de Fútbol'
     elif texto == 'https://cdn.gomister.com/file/cdn-common/teams/408.png?version=20240121':
        return 'Real Club Deportivo Mallorca'
     elif texto ==  'https://cdn.gomister.com/file/cdn-common/teams/48.png?version=20240121':
        return 'Deportivo Alavés'
     elif texto == 'https://cdn.gomister.com/file/cdn-common/teams/17.png?version=20240121':
        return 'Sevilla Fútbol Club'
     elif texto == 'https://cdn.gomister.com/file/cdn-common/teams/5.png?version=20240121':
        return 'Real Club Celta de Vigo'
     elif texto == 'https://cdn.gomister.com/file/cdn-common/teams/499.png?version=20240121':
        return 'Cádiz Club de Fútbol'
     elif texto == 'https://cdn.gomister.com/file/cdn-common/teams/10.png?version=20240121':
        return 'Granada Club de Fútbol'
     elif texto == 'https://cdn.gomister.com/file/cdn-common/teams/21.png?version=20240121':
        return 'Unión Deportiva Almería'
     else:
        return texto

# Reemplazar la URL en la columna deseada
# Reemplaza 'nombre_columna' con el nombre de tu columna
df['link_equipo'] = df['link_equipo'].apply(reemplazar_url_por_palabra)

# Opcional: Guardar el DataFrame modificado en un nuevo archivo CSV
df.to_csv('/Users/yulcardaso/Desktop/NUEVO_CURSO/PCI/Cyber-Football_PCI/ETL/scrap_equipo/equipote.csv', index=False)

# %%
import pandas as pd

# Cargar tu archivo CSV
df1 = pd.read_csv("/Users/yulcardaso/Desktop/NUEVO_CURSO/PCI/Cyber-Football_PCI/ETL/scrap_equipo/equipote.csv")  # Reemplaza 'tu_archivo.csv' con el nombre de tu archivo

# Supongamos que la columna que quieres convertir se llama 'columna_numerica'
# Reemplazar comas por puntos
df1['Media'] = df1['Media'].str.replace(',', '.')

# Convertir la columna a float
df1['Media'] = df1['Media'].astype(float)

df1.to_csv("/Users/yulcardaso/Desktop/NUEVO_CURSO/PCI/Cyber-Football_PCI/ETL/scrap_equipo/equipote2.csv", index=False)

# %%
import pandas as pd
import re
# Carga el archivo CSV
df2 = pd.read_csv("/Users/yulcardaso/Desktop/NUEVO_CURSO/PCI/Cyber-Football_PCI/ETL/scrap_equipo/equipote2.csv")  # Reemplaza 'tu_archivo.csv' con el nombre de tu archivo
#def limpiar_cadena(cadena):
    # Utiliza una expresión regular para encontrar solo los dígitos y eliminar los caracteres no deseados
#    import re
#    return re.sub(r'[^0-9]', '', str(cadena))

# Aplica la función de limpieza a la columna que contiene los números y caracteres extraños
#df2['Precio'] = df2['Precio'].apply(limpiar_cadena)
df2['Precio'] = df['Precio'].str.replace(r'\D', '', regex=True)



# Guarda el dataframe filtrado en un nuevo archivo CSV
df2.to_csv("/Users/yulcardaso/Desktop/NUEVO_CURSO/PCI/Cyber-Football_PCI/ETL/scrap_equipo/equipazu.csv", index=False)

# %%
import pandas as pd

# Carga el archivo CSV
df3 = pd.read_csv("/Users/yulcardaso/Desktop/NUEVO_CURSO/PCI/Cyber-Football_PCI/ETL/scrap_equipo/equipazu.csv")

# Suponiendo que la columna a modificar se llama 'Posicion'
# Realiza las sustituciones
df3['posicion'] = df3['posicion'].replace({
    1: 'portero',
    2: 'defensa',
    3: 'mediocentro',
    4: 'delantero'
})

# Guarda los cambios en el archivo CSV
df3.to_csv("/Users/yulcardaso/Desktop/NUEVO_CURSO/PCI/Cyber-Football_PCI/ETL/scrap_equipo/equipo_fantasy.csv", index=False)
